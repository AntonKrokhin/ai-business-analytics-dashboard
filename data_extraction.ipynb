# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonKrokhin/ai-business-analytics-dashboard/blob/main/data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connect to Google BigQuery
# !pip install --upgrade pandas-gbq google-cloud-bigquery -q

import pandas as pd
from google.colab import auth
from google.cloud import bigquery

auth.authenticate_user()

project_id = "data-analytics-mate"
client = bigquery.Client(project=project_id)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 11.2 MB/s eta 0:00:00

# %%
# SQL query
query = """
SELECT
  s.date,
  s.ga_session_id AS session_id,
  sp.continent,
  sp.country,
  sp.device,
  sp.browser,
  sp.mobile_model_name,
  sp.operating_system,
  sp.language AS browser_language,
  sp.name AS traffic_source,
  sp.channel AS traffic_channel,
  a.id AS registered_user_id,
  a.is_verified,
  a.is_unsubscribed,
  p.category AS product_category,
  p.name AS product_name,
  p.price,
  p.short_description
FROM `DA.session` s
LEFT JOIN `DA.order` o
  ON s.ga_session_id = o.ga_session_id
LEFT JOIN `DA.product` p
  ON o.item_id = p.item_id
LEFT JOIN `DA.session_params` sp
  ON s.ga_session_id = sp.ga_session_id
LEFT JOIN `DA.account_session` acs
  ON s.ga_session_id = acs.ga_session_id
LEFT JOIN `DA.account` a
  ON acs.account_id = a.id
"""

sales = client.query(query).to_dataframe()

# %%
# Export data to CSV for downstream use in the Streamlit dashboard
from google.colab import drive
drive.mount("/content/drive")

sales.to_csv("/content/drive/MyDrive/Projects/sales_data.csv", index=False)
# Out:
# Mounted at /content/drive
